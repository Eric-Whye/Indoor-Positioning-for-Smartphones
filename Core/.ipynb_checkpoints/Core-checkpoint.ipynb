# %%
import pandas as pd
import xml.etree.ElementTree as ET
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grid Data

# %%
gridData = ET.parse("Grid-Data.xml")

# %%
gridDataRoot = gridData.getroot()

# %%
class GridPoint:
    def __init__(self, X, y, df):
        self.X = X
        self.Y = Y
        self.df = df
        
    def __str__(self):
        return f"{self.x}, {self.y}"

# %%
gridPointsList = []
for grid in gridDataRoot:
    X = grid.find("X").text
    Y = grid.find("Y").text
    data = []
    for wifiPoint in grid.find("wifi"):
        data.append({"mac_ad": wifiPoint.attrib.get("mac_ad"), 
         "rssi": int(wifiPoint.text), 
         "ssid": wifiPoint.attrib.get("ssid")})
    df = pd.DataFrame(data)
    gridPointsList.append(GridPoint(X, Y, df))

# %% [markdown]
# ## Trial Data (Acceleration, heading etc)

# %%
data = ET.parse("data.xml")
TrialDataRoot = data.getroot()

# %%
dataPointsList = []
for dataPoint in TrialDataRoot:
    wifi = []
    for wifiPoint in dataPoint.find("wifi"):
        wifi.append({"mac_ad": wifiPoint.attrib.get("mac_ad"), 
         "rssi": wifiPoint.text, 
         "ssid": wifiPoint.attrib.get("ssid")})
        
    dataPointsList.append(
        {
            "Acceleration": float(dataPoint.find("acceleration").text),
            "Heading": float(dataPoint.find("heading").text),
            "Timestamp": int(dataPoint.find("timestamp").text),
            "Wifi": wifi
        }
    )
    
df = pd.DataFrame(dataPointsList)

# %%
#Modifying Data
df["Time Elapsed"] = ((df["Timestamp"]-df["Timestamp"][0])/1000000)
df["Acceleration"] = df["Acceleration"]-9.8
df["Heading"] = df["Heading"] - df["Heading"][0]
df_accel = df.copy()
df
# Out:
#      Acceleration    Heading      Timestamp Wifi  Time Elapsed
# 0        0.252644   0.000000  1091106440480   []      0.000000
# 1        0.296127  -0.043549  1091125502405   []     19.061925
# 2        0.242246  -0.146398  1091144564581   []     38.124101
# 3        0.241879  -0.312618  1091163626694   []     57.186214
# 4        0.146119  -0.470177  1091182688636   []     76.248156
# ..            ...        ...            ...  ...           ...
# 653     -1.495736 -52.793257  1103553944866   []  12447.504386
# 654     -1.847669 -52.317391  1103573006935   []  12466.566455
# 655      0.444165 -51.932257  1103592069073   []  12485.628593
# 656      1.652748 -51.840665  1103611131193   []  12504.690713
# 657      1.540068 -51.778428  1103630193142   []  12523.752662
#
# [658 rows x 5 columns]

# %% [markdown]
# # Predicting Coordinates

# %%
wifi_data = df[df["Wifi"].str.len() != 0]
wifi_data
# Out:
#      Acceleration    Heading      Timestamp  \
# 262      2.993384 -56.909812  1096100694621
# 472      3.676509 -51.907245  1100103716194
#
#                                                   Wifi  Time Elapsed
# 262  [{'mac_ad': 'fa:8f:ca:3d:6e:ac', 'rssi': '-96'...   4994.254141
# 472  [{'mac_ad': 'fa:8f:ca:3d:6e:ac', 'rssi': '-96'...   8997.275714

# %%
#Number K in KNN
K = 2

#Go Through all the Data Points
for i, dataPoint in wifi_data.iterrows():
    #Collect the cumulative error between every dataPoint and gridPoint
    errors = []
    for gridPoint in gridPointsList:
        #Converting corressponding points to key-value pair data structure with mac_ad as key and rssi and value
        grid_dict = gridPoint.df.set_index("mac_ad").to_dict()["rssi"]
        data_dict = pd.DataFrame(dataPoint["Wifi"]).set_index("mac_ad").to_dict()["rssi"]
        
        #Calculate Cumulative Error
        error = 0
        for key, value in data_dict.items():
            if key in grid_dict:#If keys match, calculate different and add to cumultive error. #Ignore keys that don't match
                error += abs(int(grid_dict[key]) - int(value))
        errors.append({"error": error,
                      "X": gridPoint.X,
                      "Y": gridPoint.Y})

        
    #Sort list by the ascending error
    sorted_list = sorted(errors, key=lambda k: k["error"])
    sorted_list = sorted_list[0:K]
    print(sorted_list)
    
    #Calculate Average distance between the 3 grid points of least error
    x = 0
    y = 0
    for point in sorted_list:
        x += float(point["X"])
        y += float(point["Y"])
    x /= K
    y /= K
    
    #Put Predicted coordinates into original data df
    df.at[i, "Predicted X"] = x
    df.at[i, "Predicted Y"] = y
    print(f"Predicted Coordinates: {x},{y}")
# Out:
# [{'error': 44, 'X': '0.0', 'Y': '0.0'}, {'error': 88, 'X': '0.0', 'Y': '2.0'}]
# Predicted Coordinates: 0.0,1.0
# [{'error': 45, 'X': '0.0', 'Y': '0.0'}, {'error': 55, 'X': '0.0', 'Y': '2.0'}]
# Predicted Coordinates: 0.0,1.0

# %%
df
# Out:
#      Acceleration    Heading      Timestamp Wifi  Time Elapsed  Predicted X  \
# 0        0.252644   0.000000  1091106440480   []      0.000000          NaN
# 1        0.296127  -0.043549  1091125502405   []     19.061925          NaN
# 2        0.242246  -0.146398  1091144564581   []     38.124101          NaN
# 3        0.241879  -0.312618  1091163626694   []     57.186214          NaN
# 4        0.146119  -0.470177  1091182688636   []     76.248156          NaN
# ..            ...        ...            ...  ...           ...          ...
# 653     -1.495736 -52.793257  1103553944866   []  12447.504386          NaN
# 654     -1.847669 -52.317391  1103573006935   []  12466.566455          NaN
# 655      0.444165 -51.932257  1103592069073   []  12485.628593          NaN
# 656      1.652748 -51.840665  1103611131193   []  12504.690713          NaN
# 657      1.540068 -51.778428  1103630193142   []  12523.752662          NaN
#
#      Predicted Y
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 653          NaN
# 654          NaN
# 655          NaN
# 656          NaN
# 657          NaN
#
# [658 rows x 7 columns]

# %% [markdown]
# # Step Detection

# %%
plt.figure(figsize=(20,5))
plt.plot(df_accel["Time Elapsed"], df_accel["Acceleration"])
plt.show()

# %%
#Do Thresholds
base = 0
margin = 0.4
rolling_mean_window = 4

high_thres = base+margin
low_thres = base-margin

#Smooth the Graph with rolling mean
rolling = df_accel["Acceleration"].rolling(window=rolling_mean_window)
rolling_mean = rolling.mean()
df_accel["Smooth Accel"] = rolling_mean

X = df_accel["Time Elapsed"]
Y = df_accel["Smooth Accel"]

plt.figure(figsize=(20,5))
plt.plot(X, Y)
plt.axhline(y=base, color="green", linestyle='--')
plt.axhline(y=high_thres, color="red", linestyle=':')
plt.axhline(y=low_thres, color="red", linestyle=':')
plt.show()

# %%
valleys_indexes = (np.diff(np.sign(np.diff(Y))) > 0).nonzero()[0] + 1      # local min
peaks_indexes = (np.diff(np.sign(np.diff(Y))) < 0).nonzero()[0] + 1       # local max
# +1 due to the fact that diff reduces the original index number

v_x = X[valleys_indexes].reset_index(drop=True)#valleys x values
p_x = X[peaks_indexes].reset_index(drop=True)#peaks x values
v_y = Y[valleys_indexes].reset_index(drop=True)#valleys y values
p_y = Y[peaks_indexes].reset_index(drop=True)#valleys y values

#If the first point is a peak, remove that peak and let valleys go first
if p_x[0] < v_x[0]:
    p_x = p_x.drop(index=p_x.index[0], axis=0).reset_index(drop=True)
    p_y = p_y.drop(index=p_y.index[0], axis=0).reset_index(drop=True)
    
intercepts = []
for i in range(min(len(v_x),len(p_x))):
    v = [v_x[i], v_y[i]]
    p = [p_x[i], p_y[i]] 
    x1 = v[0]
    x2 = p[0]
    y1 = v[1]
    y2 = p[1]
    if y1 < low_thres and y2 > high_thres:
        m = ((y2-y1)/(x2-x1))
        c = -(m*x1)+y1
        intercepts.append(-c/m)
        #print(f"{v}, {p}, {(-(m*-x1)+(y1))/m}")
        
len(intercepts)
# Out:
# 23

# %%
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1, 1, 1)
minor_tick = []
for i in range(0, int(max(p_x)), 1000):
    minor_tick.append(i)
plt.plot(X, Y)
ax.set_xticks(minor_tick, minor=True)
plt.grid(axis="x", which="both")
plt.scatter(x=v_x, y=v_y, color="red")
plt.scatter(x=p_x, y=p_y, color="green")
plt.axhline(y=base, color="green", linestyle='--')
plt.axhline(y=high_thres, color="red", linestyle=':')
plt.axhline(y=low_thres, color="red", linestyle=':')
for i in intercepts:
    plt.axvline(x=i, color="purple", linestyle=":")
plt.show()

# %% [markdown]
# # Particle Filter

# %%
import pandas as pd
import numpy as np
from numpy import random
from numpy.random import uniform
import math
import time
import plotly.express as px
import plotly.graph_objects as go

# %%
#Return array of random particles with 3 columns. X, Y , Heading
def create_uniform_particles(x_min, x_max, y_min, y_max, N):
    particles = np.empty((N, 3))
    particles[:, 0] = uniform(x_min, x_max, size=N)
    particles[:, 1] = uniform(y_min, y_max, size=N)
    particles[:, 2] = uniform(0, 360, size=N)
    return particles
        
#Apply movement to each particle
dist_std=1
angle_std=10
def apply_movement(particles, distance, angle):
    moved_particles = np.empty((len(particles), 3))
    for i in range(len(particles)):
        #Adding noise
        noisy_distance = random.normal(distance, dist_std)
        noisy_angle = random.normal(angle, angle_std)
        
        #New heading direction for particle
        direction = particles[i][2] + noisy_angle
        x = particles[i][0] + (noisy_distance * math.cos((direction * math.pi) / 180))
        y = particles[i][1] + (noisy_distance * math.sin((direction * math.pi) / 180))

        moved_particles[i] = [x,y,direction]
    return moved_particles

def validate_angle(angle):
    if angle >= 360:
        return angle-360
    elif angle < 0:
        return angle+360
    else:
        return angle
    
    
    
    

def calculate_weights(particles, predicted_location):
    weights = []
    sum = 0
    #Get Sum of distances from all particles
    for particle in particles:
        d = distance(particle, predicted_location)
        p = predict(d)
        weights.append(p)
        sum += p
    weights[:] = [x / sum for x in weights]

    #return likelihood for all particles between 0 and 1 all summing to 1
    return weights

def distance(p1, p2):
    return math.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2)

diameter = 1.1 # Diameter will be increased/Greater distances won't be punished as severely
concentration = 10 # Weights will be more concentrated towards the center/Exponentiality will be increased
def predict(distance):
    return np.exp(-(distance/diameter)**concentration)
    
    
    
resample_std=3
def resample(particles, weights, N):
    new_particles=np.empty((N,3))
    
    for i in range(N):
        index = random.choice(np.arange(0,len(weights), 1), p=weights)
        x = random.normal(particles[index][0], resample_std)
        y = random.normal(particles[index][1], resample_std)
        direction = random.normal(particles[index][2], angle_std)
        
        new_particles[i] = [x,y,direction]
    #Return particles that tend towards the weights
    return new_particles



def reset():
    #Number of particles
    N=300
    #Map constraints
    x_range = np.array([-20, 20])
    y_range = np.array([-20, 20])
    #Create random particles in random locations
    particles = create_uniform_particles(x_range[0], x_range[1], y_range[0], y_range[1], N)
    #All weights for particles
    weights = np.array([1/N]*N)
    
    return N, x_range, y_range, particles, weights

# %%
N, x_range, y_range, particles, weights = reset()

#Main of the Particle Filter

#Function to show real Location for each plot
x=0#Starting Coordinates
y=0
dist=0
angle=90
def update_data(x, y, dist, angle, i):
    if i == 4:
        angle_std=1
    x = x + (dist * math.cos((angle * math.pi) / 180))
    y = y + (dist * math.sin((angle * math.pi) / 180))
    return x, y, dist, angle

#Plot intial particles
fig = px.scatter(x=particles[:,0], y=particles[:,1])#size=weights changes size of points
fig.update_layout(width = 700, height = 500, xaxis_range=[-70,70], yaxis_range=[-70,70], title = "Samples from prior")
#Plot Real Location
fig.add_trace(go.Scatter(x=[x, x],y=[y, y],mode = 'markers'))
fig.show()
    

    
#The main iterative process for particle filter
counter = 0
def start(row):
    #If Step detected at this time point, then apply movement
    if row["Time Elapsed"] >= intercepts[counter]:
        particles = apply_movement(particles, 0.85, move[1])
    
for i, move in enumerate(moves):
    
    particles = apply_movement(particles, move[0], move[1])
    weights = calculate_weights(particles, [x, y])
    particles = resample(particles, weights, 300)
    x, y, dist, angle = update_data(x, y, move[0], move[1], i)
    #time.sleep(3)
    
    #Plot particles
    fig = px.scatter(x=particles[:,0], y=particles[:,1])#size=weights changes size of points
    fig.update_layout(width = 700, height = 500, xaxis_range=[-70,70], yaxis_range=[-70,70], title = "Samples from prior")
    #Plot Real Location
    fig.add_trace(go.Scatter(x=[x, x],y=[y, y],mode = 'markers'))
    fig.show()
    
angle_std=10
# Out:
# <div>                            <div id="7be9ae56-4970-4319-9d69-69b053ab802a" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7be9ae56-4970-4319-9d69-69b053ab802a")) {                    Plotly.newPlot(                        "7be9ae56-4970-4319-9d69-69b053ab802a",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[19.47561383591365,9.91101761571667,3.022501561947042,-18.176922022800895,19.940469190953202,-15.719104137734497,-8.375616212042424,-18.694134270399818,7.688368714898207,-16.588088331053257,0.6826881694561173,-7.645988300026172,10.891212544496494,13.91120831641252,5.222976754990178,-11.624256009831026,14.706565311282858,-9.068494477107105,-8.874498399234731,15.808103884391521,-12.079471140507327,18.727758880858474,-19.07972294297946,-11.939410569808121,-19.432849869631266,-9.265057594754737,-8.057670284059295,13.076273524008464,1.3152397602835428,10.379948802911954,15.162371689552359,3.937170396721207,-10.072814496814711,3.425396960915915,19.69219908880345,-10.211527752246683,-12.245978768822638,-13.601232278140998,-4.9217160470536125,-19.89969822583545,13.533265049204246,-12.984772850936203,3.617593737877513,11.63118608302856,8.610146629890501,-5.258854072381723,-11.962218182883912,-19.32172607900357,7.164215482649809,-4.499531134934589,-2.9961314703303614,10.353682590395948,-4.758763707439444,18.10937089872386,-2.6165096862673067,-15.984145410460613,13.995133365135239,13.926119147574255,-7.81601854148291,12.18629601596372,-6.324715448544946,12.467540242790058,18.962014329224466,6.568264442609863,-1.3916921169227408,15.191771642598326,-7.698880816484559,5.779519496952204,-2.5337961335452945,-4.026880826808492,7.4389491987925,-11.146715232262675,-12.467400784085548,4.1782086884407335,18.062865370957176,-10.16830201650257,19.951398265867965,4.876694172436451,-0.4549671063780565,-18.843832427279224,9.14331920173748,9.656112276285352,13.069408429419191,3.7730740487414813,-3.12619462640329,-0.9404316073807308,9.804474209724457,1.6628896984051131,13.436645717817484,16.73438746226789,14.066174395616166,-18.87699207546958,-12.010805546238469,9.91150709100246,3.7672270081268593,13.803922718729417,10.972921615877521,5.19011205125296,16.868913541983105,7.720665908358253,-2.9393119077189596,-14.672904957805084,19.963338078730693,-1.2288720604626562,1.6307774344804535,-18.28701785761576,0.918274828458884,-17.46683990623456,-2.5451301441645526,-1.5736602619852924,7.186599711565137,16.04700636991054,-15.179990971154513,15.212563425919953,-14.896400832428686,-18.41087658884572,14.462646693041904,-19.591959339298,0.18086172594689032,0.7951460190922504,-9.204399442585345,14.083474488581302,18.774253400433373,18.59520152812027,-19.583373998118926,-9.515242112042245,3.8457458360305594,-19.909436625258028,-9.478636896103838,-1.6509531810975204,10.77911005609543,-10.455205473629716,17.31116112854415,-18.927737471310234,13.29007522222534,-7.390223340611538,-3.762615093183509,15.491706840887552,1.390530836849866,8.333875219700268,2.8455795368445678,17.481719826760248,-8.350657851482781,-0.38112460938596016,-5.29623991409979,8.963812226641789,13.16857758791786,-2.7487973671765857,-13.266323388820172,13.525849568127313,8.213209575749246,-2.4040655620879967,15.666814269580023,16.888370499316643,14.026088910203391,12.682126508028176,13.044742648641758,-2.893099119002919,-19.92058076619454,9.583971533478813,6.499411871387501,-8.457327085436646,-0.7712858683680679,-8.389585089495357,-18.59805319041464,-2.652414365051733,-11.526935634539468,-11.060620174162942,13.67336055987223,13.114875000591319,-3.29515782394126,-1.8878761836331464,8.776774398643703,8.2 ...
# <div>                            <div id="1fcc8f89-092e-4ad7-ba6e-1b24005027f6" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fcc8f89-092e-4ad7-ba6e-1b24005027f6")) {                    Plotly.newPlot(                        "1fcc8f89-092e-4ad7-ba6e-1b24005027f6",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-1.327724038036108,1.7079517339378711,-3.1714366762086463,1.056548443957866,-0.8465121787829075,5.00729126915623,-2.6113596938563908,-4.272175207305154,-5.93157893776027,2.144800639643176,-7.5689321532170775,0.7354794076335713,0.2426072343622443,-3.714491135730782,-0.3787233344654244,-6.454912325251033,7.679767528476576,2.2196374184696737,-4.3391673455274455,4.57433509592231,-3.019348252930392,-2.9955886557802702,-0.31492617150226665,4.064932995536869,4.654518887325555,-2.5967218530523475,-0.40318719581865925,-3.4641153704064713,-2.4729336981544527,-2.022734671318756,-2.2997096416328735,-2.33296953379521,-4.280672783302225,3.195226691655443,0.29325978115266493,0.26694041325493134,-6.658470513979743,-5.309213802212397,-1.7136504490374527,-2.6469380597120367,-1.1588863706127959,6.288589547931231,-3.917708922456505,-1.9832070631789702,-2.265415660015787,0.9958277841605805,-3.1884049561079815,-1.8129749599588454,-5.0728384882801825,1.2772442643665698,1.306212886281558,0.09055711654995813,0.343202746329738,-9.186331305853427,2.1663472762154425,1.507248432871173,2.459133038435364,2.6675062779304852,1.1571214722452228,2.515231795564734,-0.16863841014754233,-3.335461051455633,-1.9645879784322005,-1.1110232906144775,-3.1994481099907857,-1.1855730881940594,-3.866776825737862,-4.722568894160808,-5.461962097138564,-3.977396066460676,-2.4894573892763905,-2.9758004758222283,-2.044010079182459,0.1706689744352492,-7.0384662995091904,-3.3967743897288836,1.356423218774715,-2.403616939856965,-1.1844387214496936,-2.5894166831262764,-0.5255790796929785,-1.1050479552314667,-0.9606709305277606,-2.3589975985690925,2.0451088282280496,-0.3591243724566743,-5.984032686622216,2.9511638099394872,-1.625694054315811,-5.191357241194997,-2.28856776454327,0.23206898929960507,-1.6791681232165696,2.3169664150323426,-0.1857918209471182,-3.2744538140997106,5.017940249629369,-2.8220558096612605,0.8725799541002077,-4.727405941331974,-4.3156555506216385,-0.1609285942133829,1.2872948069898078,-1.6185493514651998,-4.254398091525139,-3.085186496641535,0.8198389520929183,-4.086614749809469,-0.8235468388862759,-3.524774831388126,-2.7367365364938765,-8.926296760558111,-1.4892654505530176,-5.073360864847297,-1.985558922021053,0.04084688735172559,-0.7750059428445994,-0.7888699175921192,-2.1198328188321507,-1.1963224375031924,6.801339731743862,-2.994238539467884,-4.43241997987332,-2.128399370813926,-0.3092261503117688,-4.244455167174566,-5.327231101842878,-1.192486495277532,0.03375769574450427,-0.8050412926164954,-7.150679155514796,-2.869549915718829,-3.3600999771307984,-2.143597900434891,-6.059526607098459,-3.740901480138617,1.5458267071668528,-1.8009849716612107,3.2181005587385494,-1.9041298147125503,-1.4356655558446192,-3.082657948726691,1.359603270118903,-2.7710934264499283,-2.0870716515795893,-0.3120883503810724,-3.0924160201239053,1.193919482603025,-1.5801406670260634,2.9406955418528575,-0.2524361688409529,-3.195529088948792,-1.784772018267534,-5.325536073927017,1.0494076370378862,-3.63963380872233,-2.627469473253637,1.2816270060858403,0.841364711842602,-2.0181451074073293,0.11638259409196672,-0.5225170237176243,0.8509011456503146,-2.787651066820871,4.511883233920574,-6.9796456878720035,-3.530796608650973,1.600483338003927,-0.8343379165909898,2.2192846803786095,0.03318 ...
# <div>                            <div id="4f63b8c5-2bea-4e0e-802b-16f7133b14ac" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f63b8c5-2bea-4e0e-802b-16f7133b14ac")) {                    Plotly.newPlot(                        "4f63b8c5-2bea-4e0e-802b-16f7133b14ac",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.806467506253145,-1.0784537365568325,2.856300181597497,-0.152514082473866,-4.623485915556481,-5.581734439508649,-2.160883199712117,-11.693063073300657,-1.2973129710535893,-1.9223408428502147,-3.2655667748394652,-2.3171231139365434,-3.701341338758459,5.149727899865022,-2.942652445817596,-5.856173338147345,-0.6472090329022222,2.2349817350574277,-3.8591030861664444,-2.2008147682542267,-2.4059821218046182,2.967951089996267,-0.37327128117763975,7.8529722920049,0.29581844231796617,3.5918263022260235,1.3478262435449,-5.320316946644146,-0.30608963875308315,-2.164979938232112,1.0422117485301239,3.4457074138169284,0.525433040264756,-0.5505363539280821,3.107293302412579,-0.453517613670528,5.167887500983621,-1.1743085119173098,-0.6634959446920917,-1.1423757968913708,-0.7324135777126106,-1.8690387357351477,-2.496755017763499,6.704592420358731,-7.039225662921069,0.905525047079899,-0.24029548176100765,-2.314200014568734,0.749662484706708,0.23869578700220528,0.07471381529954582,4.507582052381405,-2.14459924305078,7.576546601047591,2.688486391860125,1.136409892827131,-3.745778693846707,-0.1622825480651764,1.089043384438478,1.7413357310473645,1.0285049698760889,1.4739251720731097,-0.10138596756866203,-0.4321906680794987,5.035346681919355,0.13427586631245145,0.0157546984223198,-1.3846042508207297,2.686972884610146,1.2600405925064324,-0.12980129046314323,-4.972852597805182,-2.2850091390238303,-1.4400806052211905,-2.327762982754811,1.9741398659910203,-1.8812220049966615,-2.5981593715475713,2.1476646063906424,-3.1804441879965837,-0.5786828135731336,-0.45611606669573934,-2.898698226061579,2.027537086512405,4.434343667175514,-1.172680660982665,-1.903663335042414,0.06234374141155952,-0.21111619968033013,0.8564571224988956,-5.089779915440069,-0.11937081635182922,-0.7608592127409406,0.6141631999023218,1.628075055629651,-2.2347808382831897,-2.278675805854931,0.4055357399431425,-1.0563598557286082,-0.5057415294163707,2.4285461552749803,0.44626448973423166,1.2758500320627517,-1.511205908689672,-1.7575050072286138,-0.4342385291361921,1.5663056141816534,3.4591239288709374,-2.412300597069205,-7.005777224906842,-1.228346964956567,-3.350268624945186,-3.2743417075309145,1.7990838058081513,-4.494610745588421,-2.438745377357116,-0.7278619881279171,0.5982815671961129,2.457117516338231,2.2929737558979686,-0.1270187418555226,-4.458618409036253,-0.43005543663011225,0.6554366457215861,4.851278899736909,1.5128913655436118,-2.502227968259854,-3.4488455269500387,-0.04454850094865406,-5.377254683197968,4.7679567665314,1.338735625102411,0.05039530232181966,3.1911246750970363,-0.5485562266448663,-0.9783817293357859,1.8921664900006911,2.9576898118033124,2.8692303316442103,-2.6634907276523014,2.5929019541306246,2.9667278873382887,0.8240273408787939,-2.4869537055894195,1.0700899320140411,2.7448134808709375,0.945156710913992,-1.5725887044892832,-1.0266885530884071,-2.3910453278141324,0.5853812120716181,3.282635338433213,2.6077432093091213,7.472823162938903,2.722394852550401,-4.88275442814599,1.6913392629798851,-4.182090390023026,-2.325653922963054,-2.6482960719395137,-1.3133137742563297,4.803586379421626,3.068404539581914,-2.1296988464694975,5.4251647071634705,2.8694418489373645,-2.039437235174709,4.920824947814834,-1.2604271966474307,-0.059691446451031416,-2.6421187609294696 ...
# <div>                            <div id="c84447dd-e59f-4edf-9898-256ecd731a0f" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c84447dd-e59f-4edf-9898-256ecd731a0f")) {                    Plotly.newPlot(                        "c84447dd-e59f-4edf-9898-256ecd731a0f",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[3.679471885763757,3.276384862654779,7.838635908806771,2.4605875959565386,3.1750870028216616,3.3723450933386356,5.848438151008764,6.880731592448241,5.753292633408867,2.2978276451020765,2.8785762822618706,2.47929833396975,4.057603981320069,3.2021970500128543,1.7208745456582732,1.113047990606439,-2.030357088228148,5.250204154772712,-3.568147898207589,1.3933262059573184,2.4118299792823885,1.9053399591890383,1.456330638303978,4.023426404406126,-0.13967391977962862,3.1289980346046393,-0.769063410553879,3.7164136689108656,1.3436493591486,-0.98002776459834,-1.6082685794352116,3.1322785277530563,1.9725525901211256,3.5932333776590477,7.586247863969002,3.7797184002942004,-0.5320910068767521,4.780903568275043,7.293994894014048,1.2843080299398806,4.269680696602445,1.2791240013078653,1.3155820668277012,0.7426106240073597,2.4173436324867352,-0.28826431011551357,1.9784188756071523,-2.436296629444674,4.0043129422059405,2.5513588562895433,0.8564013430691164,2.468096927589453,-0.13217543459454673,2.6206930153430856,1.5271295866241463,8.016580800568837,2.467579503926647,3.65405094166639,1.3272597182253678,1.552276061247153,3.65082370493384,3.949385421026573,1.3409442421526474,-0.894505623016105,-0.8840327333996703,2.81520438161571,3.022918305642862,5.7615731740146945,-2.07773625122048,0.9628271054480809,-3.9367012421033154,5.770434436636895,1.8670480722526823,3.635331680046142,0.827046774582906,9.710240632735374,0.7585163532227157,-1.8880996301897905,-2.1210004606865156,5.339209533013122,4.309742876655379,0.8611101165339459,4.216006201055582,0.8682067301505707,-0.11170331160813651,3.2859905663573032,1.8610325732979136,0.08890532656949368,5.4101550090185295,3.487582550336653,6.550303581567878,-0.841426346028725,2.7356441943613268,-2.5499549163156274,1.5896535194637456,6.051200561713427,3.6656220199963623,2.7926914666342957,2.819826064185656,2.810215584320858,1.3540803715769094,1.6192428366768739,2.2729128657751394,2.013018625976911,1.9295330335683694,2.262940726173157,0.07167658475919503,3.8003595652771094,0.5251531365819933,1.3940013140367087,-0.9487582142895734,6.615032766823215,3.7047976984349535,3.4840021554354115,0.3330660325383281,-2.4405262854271284,-6.493762846004901,2.6251857509772423,3.871400385687866,2.7155246683294116,4.580821726087631,3.7073884472791305,-4.427870433408595,6.03077524787271,6.357631444317118,3.8420604410967325,-0.9150475198389159,-1.6841087328343327,-2.9598580799884338,-1.8976820211130523,1.1355406044338296,5.511916590835114,1.32025770873485,5.041114502516055,2.029456931903591,0.5505113869506606,2.6131815065992363,6.614899089809575,3.0277530455891073,3.3914537819963115,0.49007490880443494,2.1477572094798236,4.126580082479256,2.406528153237646,-0.8081645707098268,3.324824269472277,6.328548799997539,1.7183305507077193,-0.2568224579867331,7.1118109343840406,-5.272098884424698,4.515900096122298,-0.4501717236256155,1.7392635671495955,3.2196636999098667,3.160256915964557,-0.3082648992020922,3.545503798097915,0.3729501346858104,-0.05999827811161618,-4.40421993530071,4.943653327040305,3.233689373101196,3.6876761277794063,3.4170962755646315,1.9524630219466281,0.7856113047527017,6.326778470570305,2.675232823828421,3.1617814934908086,3.3243989750952263,2.6011421450956305,5.895045003620654,0.7816257664161846,-0.87746164412204,4.3 ...
# <div>                            <div id="514a9847-65d4-4212-9c30-d8f87196e756" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("514a9847-65d4-4212-9c30-d8f87196e756")) {                    Plotly.newPlot(                        "514a9847-65d4-4212-9c30-d8f87196e756",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[5.79421612260079,5.9832178645044145,-2.3579292509964516,2.11278645976306,4.557081182142987,5.108727609870506,2.575005688410568,0.01448608528865769,5.3761255979707885,1.9700006781462096,4.695579442930344,4.466644116177538,5.548298893209884,-0.4839545904231386,1.33209176601471,5.085336936213678,4.376915039884246,7.335431626297932,8.704685079614643,3.6967368123705358,-0.34350914590627823,4.132951417489993,4.170295324923168,5.137508600275311,5.296677280502808,7.552466840474969,0.35710070912153036,8.329912332273224,2.2432925029344384,6.854904764000853,3.119949793251631,-2.294709601810049,7.785835058722284,6.9383965327877855,1.9486425706574328,7.28122646536036,7.3929780720803535,10.092502192202478,2.847617825241655,3.2333313412624847,1.8959291788472297,2.6227353613261224,6.631713744083975,2.691898150426601,5.263908936132908,2.7623569158813672,3.8487846299388404,6.470211610308966,6.421830629153352,7.914284578394715,0.29425835805421663,3.5433825408846187,1.8451966469990095,5.353590242103392,0.7426201315169036,7.725077255558632,4.7117401136641,3.1364377075376746,4.556212722982707,8.306944162079775,3.166902100073954,5.1833902098835685,3.3136700665613614,0.12740437503342328,3.6568685331712003,1.1848790943258192,4.706786104842939,2.1992247321138465,-0.8286180364169748,5.887327145574689,-3.032910744699193,3.54391219431771,6.416272375868127,-0.2340830097007247,1.6025917676688484,7.335849736330779,3.2977748914878497,4.626981937007265,0.6544528452622531,3.4889482160580854,7.7910341171251165,5.101351693486385,2.690204156737442,3.7259053816562,7.5330741806602814,3.050466144390077,-0.8804691488814749,6.124511599063257,3.452530220535781,5.059358612900808,2.235422456919257,4.378966921977724,-0.03960659689174584,5.888789916782327,5.872841140386166,4.46480818548542,2.4536115091809374,0.9276982815352506,4.915449574618646,11.200232624105638,3.263828580487308,0.0410115159940565,8.786016038810732,4.974193204965836,4.226625297252731,2.6391824882875503,5.887631471045463,2.082437091555972,6.060618084080549,2.9956816954370415,6.359827409988615,7.465340207304841,0.7497955805080907,2.782410941532805,12.870935464468559,5.392403804300329,4.8033256001906075,7.27742582671328,5.956095921161527,9.44775251009348,9.519035061444525,4.692533000101713,1.1563708710200524,0.24355772317475743,9.586696252774189,2.0853613686915056,5.557448759986325,1.006392697924853,0.4710694569168963,10.120468031380643,5.307439892937653,4.560766150520736,1.5846631464986838,8.37603040642512,5.365159451806422,0.9226401950674656,5.728176809046543,8.991776964894228,3.7268783015160807,2.243924271535357,5.889608344157632,0.8183470207668462,9.433896187630289,4.5990730809522775,2.1625959923637526,4.791355172829526,7.038878958205617,7.114039607954831,5.15116729883838,5.2235340870235545,4.743937679267335,1.0096526865193423,3.1692334638778554,-0.1411301433920613,8.7727549131332,8.193153424685608,7.496315700905387,2.255378720019006,4.414553993025178,5.159500234183558,5.343854484721274,4.072710977477067,7.34113289400362,5.801568032738889,2.600398977743126,9.471336134431812,9.677065660747445,5.272188174853975,5.032482339247273,6.368272322181184,3.1316624566277627,5.991918048057059,2.090381713278842,1.663734428729791,4.742334983001258,2.3598003822983205,8.462642805692028,8.103877302771423,6.127181632407 ...
# <div>                            <div id="43c9130e-c9ae-4810-9d44-4577c9b142ff" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43c9130e-c9ae-4810-9d44-4577c9b142ff")) {                    Plotly.newPlot(                        "43c9130e-c9ae-4810-9d44-4577c9b142ff",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[7.928255450446105,4.214347959795399,4.273357564296492,3.3610494223268383,5.4203344051575115,6.3003992969385605,5.576284915472541,9.484880851204425,5.876781990160204,8.60255063151319,5.909986250146589,9.257821999812187,5.865367000198848,4.023687734927938,7.5168894371754735,9.023542901817851,11.00324580026011,9.865716180102616,7.245624824111099,6.896546342258295,4.2226080769844465,10.593964069965388,4.316602415065391,8.186336176676008,6.395674062899356,4.658086386741715,3.0682758420173517,10.347417625726656,7.5668627646650535,2.052302557803359,9.946629051020873,2.077020812203389,6.339437409766886,4.552962125642919,8.200200801463833,9.375464211854101,6.387746936478708,4.876749057737882,2.6208094926384407,3.9435762390275038,5.764226676362305,2.331693365791372,6.6675003087665345,10.283124099198181,7.678752340921573,2.216842857090122,5.468179915560893,8.824180956248243,5.093469875425272,5.3430076137705695,9.438055274065327,7.086267297335942,3.1936845773981126,3.6911187393452365,6.693087235282745,11.112992864941072,6.891537921985387,13.499618527032943,6.541298882911876,8.441734514821551,4.776879211893322,4.6267501980929024,7.377768914159184,3.459501035913573,13.58388019447709,6.64773283485564,0.28437176867781044,6.924568906397486,6.968553184482679,5.254517788372304,0.6019461201792424,5.179832994366307,4.888497139065077,1.2420368974343,3.566186559412,4.262692063607192,5.026592119093584,7.213787880732297,9.651192947495518,7.573357765702109,4.747159161441487,8.753149816079878,1.0074836201446722,8.87637456817346,5.632372792040079,4.880810782013577,10.45424019586022,6.919636552356426,7.025124967952697,6.0729137771641275,4.501025294850495,8.038894699019535,1.3600106877502744,4.200611318721657,1.8770694796860798,2.872530285704639,8.48175551731778,6.728954279464212,7.2558374704787365,1.7368284711820374,5.224986109452469,10.941667221664936,1.5422004540111987,7.6873844061904375,6.211060840771876,5.516593894175461,13.500064261757256,0.7716727809803299,8.117786722988805,5.147390967980804,6.033291936303204,6.801734866303593,5.517637566970034,4.557990668426171,4.9181385339113834,8.965243480720147,4.701171462058807,6.978063214288548,2.2377769724647845,5.026774395234222,6.469753546625417,4.513456539572847,7.650835732693179,2.327069297667559,8.852740998107244,7.114343592092409,6.270353188256213,7.180740382466295,6.498420433676763,7.295190398166141,7.794733032842563,2.865163689902053,6.168046510927828,3.2004075307474102,-1.5781336460901976,2.295389552936788,3.83267105960765,6.537862186418571,8.007372462403866,4.014687644924935,7.036165638413083,3.1631469227140405,4.241980057221893,9.375010421388286,5.102383578900509,5.481060184099469,8.35470329810198,0.7794304523817139,9.382504716378023,8.485522843481114,8.701633577597786,3.659236298073682,7.950825105172732,4.587094431755476,11.242533370245779,8.435886654770172,6.907516415198703,8.572619894115025,11.498944202756775,8.799940303353932,6.738816156825482,7.202454076184718,7.017671725988965,5.920211326281149,4.520627491431599,7.46172687505557,5.69510831854978,7.984729476529426,12.5759511354931,8.773085258889198,2.1949125433824035,9.90729029072249,6.726684529213711,5.463234683055084,10.827259647618707,2.6115979619642973,8.298159478220363,7.3527466130191605,10.97415805505354,4.560485967500016,11.7958811062 ...
# <div>                            <div id="2e3f5865-b411-44f4-b8e1-ecdd08a425a0" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e3f5865-b411-44f4-b8e1-ecdd08a425a0")) {                    Plotly.newPlot(                        "2e3f5865-b411-44f4-b8e1-ecdd08a425a0",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[11.623157725442056,1.419165644834635,10.617671958283047,6.652625134188554,10.725839378448093,16.326142244144634,13.073289702639473,7.492515026354786,8.591617540126625,15.171656640419657,-1.899179355025888,10.169512308251567,12.575650351092232,10.63958540192126,12.409426223341708,8.921312877317018,8.481867679295187,10.196334443543165,11.449952688408821,6.180293514830254,4.818891058806917,5.3316892291037234,11.161614018954243,10.363366763760988,9.632018692138958,5.794263684652968,8.802887827134786,10.731803713465764,11.680514867151558,7.455769238204994,8.793108020750601,9.293403288168532,10.768316707009166,8.234463207886273,15.279681999708702,7.199767829002454,10.526294260967292,12.004736260234967,6.036933829984986,12.066556517824665,7.527129745925541,5.6736357283266585,11.017085031174458,6.317630090054285,9.858036603941022,12.054105960724716,12.016786824643594,6.364139023286915,11.324548169146244,13.373669433120725,-2.1712198484157845,12.317068439664167,8.229493566872947,3.0542215003186257,11.77677650311876,8.51219239997074,7.988795172263556,10.643354985107072,14.546356573217386,8.23856731242553,8.850980850630744,10.267299418046175,10.235149116415055,12.660401945963624,13.666542897908851,10.967002817264998,8.029288644830867,5.7534196040043,14.328503643183547,9.126049758841003,4.435444760399447,9.681391839473571,14.374532895844014,8.539728877467939,16.603852374625784,11.687943993755376,7.019539784787845,8.39821284179061,9.68127140338371,7.494882337142627,14.249142349241719,7.635241890951418,12.18158758764146,7.522255776046535,5.285697785465029,5.683220624027314,7.813590900929762,12.139286992170415,8.988135797266429,6.142312389946786,9.23628444868991,9.242521578100838,7.796427145544329,8.735307221690203,5.767929114227703,12.322171183280602,8.477215153085247,13.117997448416324,12.010437762427596,12.023953586749801,9.757305073255825,7.656164969934624,5.708640434016518,2.226134861006142,6.3150543363420315,7.597023189917126,12.223303702745493,7.489226558075458,7.227730143016505,9.9792492820588,10.737637669620366,5.920496868032221,12.393160343777623,13.138691090021808,8.280035322784068,6.971746938715127,13.087822113668649,8.019566817826107,12.020105404152371,7.22459446558531,7.9444360459359045,6.416808342019121,12.922763132192276,10.328632890202888,15.303653444633584,10.918264761682597,5.280275388614238,8.551378094172753,4.707554448419582,8.906533367306245,6.310098337926939,10.424945405162582,3.8411758661446687,12.282989231804285,11.306749534798854,12.779271546379912,10.645786532458022,9.73829043573694,8.245157424238283,10.771644181630206,7.3203366783586645,7.571318942779831,5.644348985764761,12.799013554363665,12.941689780713617,6.003120589745176,13.38158364520652,10.033334399255311,4.208949911207781,11.616183894795945,6.024296515622286,8.809951365215527,10.318835435380041,6.698150374919397,11.40755110240481,12.157882653806078,9.99557142346164,9.809560204156066,14.05281298106295,7.859038107225476,9.56452429833826,13.238976580284156,12.244560211078,5.835444568276041,10.467840579456011,11.044690897070629,10.166670025693847,6.907947182168655,11.111823986222191,7.546289573256934,12.075552371015645,13.089000283782205,7.476861595407168,4.067740766761277,9.909644758957484,7.928292660152759,10.996871518830435,10.866523888998929,9.463989196 ...
# <div>                            <div id="000bc654-7788-4607-ad4b-3ebab21bc926" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("000bc654-7788-4607-ad4b-3ebab21bc926")) {                    Plotly.newPlot(                        "000bc654-7788-4607-ad4b-3ebab21bc926",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[12.923935413664484,5.270712267042292,13.284451496666168,11.418287676948133,9.497019167066728,15.012815027484617,13.984294321756087,14.408080070576014,20.783906268578285,7.288195153544835,14.226466425461627,8.810240937931953,9.32020721886594,10.373472065138694,10.112323115480448,12.993426574934311,10.900005310350464,12.862719519319374,11.768788267964938,11.7506927699519,7.573088239370204,11.927546610706832,10.551532266421106,12.109531935579446,10.955404316957168,12.357117447430777,18.217096877382723,8.651202028038945,12.831668167922299,10.283912544374513,16.554733293560787,10.831472283678352,10.246025804066937,10.259860636292263,18.54556019870857,14.85403782867674,7.119172241113949,10.161610800063425,15.904679513816147,14.319569945702534,16.311717161711996,8.194989990685624,8.676734502216476,9.77028130851909,8.468931196243352,13.142598651339792,9.633607362256427,15.233854014621919,10.210746981537662,17.891025077842237,11.606542392444819,6.788163429840937,12.498676443890453,10.938087247791843,9.22108614177309,7.435294336030575,13.745599359344615,14.783411508945337,9.669878805827514,9.381787305081879,9.159298349164715,12.076583436128995,10.782433403116377,7.000084737808962,9.461347155028804,12.354840520071802,12.893616607360794,4.8254510487104785,6.7250942455972735,14.86169348044903,14.880697361752826,8.577067690725077,10.817112915297242,15.851709925368297,14.292385232450656,13.354758637219895,8.450688499631935,18.520808202925306,12.531298676196847,11.95653189565435,9.622702627561281,12.577031702553287,14.502250540288404,11.933405677635621,11.627160286811497,12.038542946722716,12.763537830790694,8.711703540921263,8.003004731136766,9.74500810471109,10.747192285162676,8.54345189189913,7.45956125592359,13.988311201246944,16.80221951004347,13.712896542603794,14.730987134299571,14.129001117241197,16.15370720097752,9.391742529215602,16.452578956877414,18.28436459443628,13.382573260157876,9.442908603753052,14.185011891059641,11.14315279272129,13.177829528200803,15.269921516569283,9.388489076423296,16.59773801696008,13.59063286822727,9.616383532929445,10.994418086069626,10.692154918016673,17.49658136885801,9.453325415908829,6.031112796443181,13.332347458271189,14.400868557543328,12.469902494280007,16.865776107936874,9.357347125412847,13.115625636081624,10.489419721862058,12.1149558513148,9.076700966445582,12.10000017832155,12.557321922567384,12.660176611382958,11.187832891845995,12.343674172617472,11.951146898001857,15.169705669536523,12.831725939023494,8.417918213985349,8.017476141815997,13.340008704703397,16.68673281691653,8.071941278425943,13.435896394031547,12.535322144967656,18.743544018273177,15.6148067443583,11.300173636680531,10.260444314310636,7.153027675735167,15.577331480055088,15.573054992072949,11.521138074004059,10.255588327092802,9.54436241205599,16.720442915052878,11.15162145598263,5.711358297155487,13.353427824340645,17.5086822495082,10.401777692129404,14.78315830772917,12.31738440961129,12.757285497908383,11.38606389822238,12.33104207503412,5.922121858001815,10.862205969614957,5.7313306065758365,14.344480727515482,13.596699847251205,11.656261251161057,10.241145276398957,12.451058683572956,12.463484767077587,11.34499557901073,13.011613962161874,8.707682914685494,10.136487579774215,9.429463863545088,6.8858183684780645,9 ...
# <div>                            <div id="024aaa6e-ff27-449e-a2a1-3e89adc27a22" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("024aaa6e-ff27-449e-a2a1-3e89adc27a22")) {                    Plotly.newPlot(                        "024aaa6e-ff27-449e-a2a1-3e89adc27a22",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[12.349092783624496,16.745554510427937,13.66718484304721,12.908938953002117,15.225075968304878,14.339114643183063,14.296863813605045,14.216613778567492,9.395969657640718,13.091997695607114,12.26438410092084,14.352105546941191,15.232155113702664,23.047015490420566,6.801885993494559,15.29763654976674,20.415638028690616,12.330311025927365,8.40224557740773,13.280544133289983,10.180053244010228,17.74779284120822,15.786726532893088,13.783220331317741,11.375954643517993,10.040440541890863,15.069420049063394,7.79121324052234,14.031298260929368,7.54895496753075,16.73309037989131,14.720017112046579,14.188902258462946,11.956606655865789,14.87911594721424,14.270386331614382,11.130894867339697,9.77204818287775,13.848356052693553,14.629623745241313,12.431360163238752,14.985818246978276,11.058209357431195,11.095535446692383,16.742175906879535,11.6705128153382,12.421973193983108,16.284130849568804,14.467453559921026,18.699570851932794,14.365229053494364,16.118683034064485,8.862109190431177,10.919664386117006,14.26316035543786,16.057565574980533,13.449365879990115,16.6634971288842,12.915662936677844,15.393759418758648,14.861722832193223,12.20852050415424,14.032266272830766,15.949050234482304,14.83233949294184,16.01705437856957,12.646914870531342,13.237223627511952,8.164791779234323,14.46752858086992,11.406822645977519,10.66109355710023,10.002958478152514,10.94656937560963,15.84726697082723,18.14405828555278,11.62190611237516,10.254639723865822,12.038337425064855,10.413035741679602,10.625035345131181,18.82824913775371,11.324892725599327,10.224905560571095,13.65890887605658,16.960916428914487,16.464321349846088,16.248829064535904,11.975463570463598,8.756120295041532,12.919646189233713,15.697013442099177,12.548266157482384,16.214488439136616,9.059875601394557,11.678845356157003,16.83275208316017,14.210228240885417,11.260260310669254,15.044332303271332,10.44657187533133,10.497167106442554,12.444869120731855,14.160701126637058,11.509924823141887,13.060889699077698,13.655800683962841,13.818121277967961,9.893380198094619,13.023784805184654,16.55535282824866,9.617311570212555,18.982601810641647,13.856956282411387,17.592109000325166,16.027354737269224,9.645050314281733,13.008625987450941,14.10136638634091,11.710715949333919,10.08971901166624,13.207861914651644,17.35461256460843,14.747627805068198,11.280415086428711,18.754106861109875,17.909533180689053,11.945421762763814,13.863477443597999,9.034428494560068,12.760460709115158,12.825014091847917,14.411270818298043,13.224142061884347,14.96497287167746,15.8488358616281,10.891856139422114,14.698945642667146,15.511191795434245,19.53319075647563,9.640868868495172,12.201310286079202,11.830666661871817,18.632817871704585,7.097454996773981,13.564715796812866,16.645076430681762,12.914155046373361,13.21970886989471,10.479132613271155,6.338918167985744,12.78603375359404,12.535501691837514,15.971109773370273,17.953615154242463,14.797642656406815,10.620535678181355,14.93202902428083,16.37394832449649,12.466909074118762,8.48874152695948,19.149786659066294,14.903671711679694,10.313661451166592,14.171883896306868,11.107620625443795,18.253449183400008,12.363125152614963,14.140306378817638,17.927152432044057,14.43998020561416,15.18476543153253,14.082925398599242,12.63862541340197,12.404032827410857,14.146217822744203,17 ...
# <div>                            <div id="a095df50-74f7-44c7-ac59-5ac53cf630ec" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a095df50-74f7-44c7-ac59-5ac53cf630ec")) {                    Plotly.newPlot(                        "a095df50-74f7-44c7-ac59-5ac53cf630ec",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[18.89295625941699,17.951920992867624,14.52124205971417,16.94571762610588,19.412305561963954,20.383838478342618,20.115409867200935,18.7529365915635,13.932355018737852,18.998280392325903,17.819403108418236,19.686018831016312,10.954958306295214,15.836866867089986,19.51351138964833,13.678597749337921,18.220931085885038,16.91755046153509,25.548459819654525,13.944264667244052,16.600235648736383,17.9398632910952,18.057350726026204,14.995132791432283,18.887010916386863,20.065674967661845,14.531680164982275,18.432115638938633,20.692262726879,18.37038336831155,16.075875304771316,14.969767855303449,19.294131326855414,16.182179767425254,19.675493228247607,10.348777588073482,22.865879172162536,17.157799154974253,13.209318510862264,17.949072904173608,15.537989963310707,16.299419129086857,13.436879323049162,19.456638378039433,15.077535754788286,16.805433029148475,18.781427484960062,18.734526420405803,15.92955486571482,17.19394566807434,13.683459664242221,16.839613901153346,19.905013693911496,18.300973329913937,15.833030595494668,9.088979575739362,21.595866048350874,12.994989273770043,15.427740157078752,14.962850037527694,17.880712664253302,17.6000523947246,15.522428119748541,10.531116147328202,19.19436692453786,17.273702971158347,16.12037256517592,13.422845929671864,13.16419007310759,15.864847097429756,16.86020664132665,16.03352075027758,13.484735591867043,12.615570752407425,20.681916924761243,12.56600837279797,14.29857594272092,17.409408241138692,14.68617940228521,20.99316359317405,16.684028958438557,15.809668247281056,11.265160163602111,15.78589707984221,18.950815602345827,15.369861509711882,20.79471919640194,13.20344321384809,20.966039728749486,19.162213965086554,19.00976081690686,12.819084044177965,13.423719881086202,17.73647844424686,12.781325715764732,16.886639247763597,19.114711042498737,15.865718816206154,11.872544134027244,12.879477840581654,19.06469842835868,17.899272334840386,12.979185901793354,23.107962133442385,20.79573421789555,16.513537522942997,21.3609257893607,23.761432863600927,19.41068241668777,10.67759192953737,18.736060013811553,17.46155815513212,17.049277366314104,15.621463505428892,15.15726259026425,19.204878432459026,14.143112095839843,17.538617540723216,17.782891378031387,12.952960801169002,17.124467745194533,18.82530475951855,17.971244003041594,17.622848581067487,14.167106282753256,16.428660515794114,20.972283156640223,14.046253368293943,12.773432044115186,20.352101129652784,21.194197428189327,19.699913666760967,19.91388042995151,14.441427220906398,19.97390106163572,20.696526361197098,16.51500279499398,15.574477272228632,11.936551957397027,21.825073080582904,15.624102247952194,21.159376937331125,17.717223001089447,20.67809852659278,11.460390573881966,18.547377756009457,16.40966456635526,19.521439539304684,21.006508245943813,16.90063218553336,19.034896352479475,18.78946808657677,20.366913518447813,21.62836188871541,22.0867706464905,21.028655700921675,18.57613667340245,12.65844284013771,14.77117650850739,21.48587161156644,15.723653921678556,15.173640902586019,15.237915572529483,14.80861130905964,16.782021130887028,17.28803611927214,18.85708180487749,19.330173161115685,17.738697006718162,16.079988251424368,14.42111724233457,11.19523297006769,16.629641419635835,13.838497806726132,15.896033118132587,18.211544539325136, ...
# <div>                            <div id="9df8e09b-7ca0-4511-8b9d-f6ec6aa6bc06" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9df8e09b-7ca0-4511-8b9d-f6ec6aa6bc06")) {                    Plotly.newPlot(                        "9df8e09b-7ca0-4511-8b9d-f6ec6aa6bc06",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[20.517277424879424,23.606443004248405,20.25991053817551,19.10233054112421,14.44970933948445,16.890331315038175,19.4535879765226,15.128148871662665,15.479927590080855,18.524620236758917,14.570182362009922,17.896378326340272,16.28707537195788,21.692568980979893,16.429564013465193,15.315030041556524,15.745276603719047,17.67841053939149,16.91654350394784,18.910005208413345,16.76856279322232,22.40417347801685,15.737186672329102,18.943382498146192,21.061265240229094,20.498263912270232,18.473848770076046,20.090415278041178,13.505374284220355,21.4081990588723,18.9294723713583,17.655811321706235,22.346235622860128,11.42793914840073,18.790640505938452,17.436570586327324,22.002740336588623,20.59620124476001,17.473269900069692,14.243137244664183,18.906154420916412,19.989355610558306,21.910384965309518,21.331943296015403,15.457288055528931,19.329179922798094,20.80909316775566,20.83007727457676,17.599059294514937,20.158227723521144,19.5573288535447,14.42868870278982,15.978721144739183,17.354248606948303,19.171634487570728,17.133337669816044,13.19541465623124,20.243363666994988,22.151516701477313,15.81401789879057,13.891979669834289,19.324726945319714,20.431574289926346,18.80904443619869,22.59517610797509,14.688667742341092,13.4061154822517,17.732065512482194,16.12031922454738,15.503643728787173,24.362563682340227,20.42932449626299,18.889965182517813,15.476651721248071,16.553826213214577,19.885821676894697,19.142375024059003,20.346021921158396,18.53301797481744,21.078038151479596,15.395820373216523,21.95793977974387,19.503576816158287,20.216907473963047,21.02246873922321,25.181905334410505,15.812810896211287,21.691559897823602,20.709872394930706,20.261134561209705,23.446105632566685,19.810377340894064,14.038381018285426,20.82190087909178,21.635693312221157,20.65699402195535,24.057089850939246,23.533556697379538,22.71895795242375,24.2775189347686,16.543431424373992,19.44058074222132,13.983150764674466,16.689760105701875,24.22560255477076,18.036918433057792,20.863293111291156,21.928025232025526,15.70198029977445,16.692498857645287,15.227828768311968,19.253496348983425,12.826208004750024,15.527379919239749,14.859127576359633,19.346473281996253,17.79689787565799,17.347579858036426,17.196564971312924,20.42709464426206,16.249049091897916,19.123634349878035,20.476730567485575,17.037319099775253,20.84368610414501,15.349500517589291,21.519088203367055,14.393036515086534,14.963482950119555,21.145470510374714,16.784071922615105,19.10253359258973,16.31536341434919,25.214269974598707,17.251301672614535,18.02970489806564,9.257385738107972,18.717805303081448,17.862846286864137,15.690155340247285,22.347108733250078,18.34743958134085,19.17878257606693,20.13122884740633,19.914688467941595,15.302323053494002,14.00582340771652,20.997762077280626,18.69414418763921,19.522909758063275,20.886793073631495,16.229031121545873,19.068497632899387,20.595812360429623,15.714193209394116,20.167996502885927,15.152616076670189,18.23801372772333,14.870634721592907,15.828354544578636,18.46726594507645,22.350917867803567,16.358891864627527,12.39794727135323,16.80564923608314,18.279824691309585,20.69534478911829,13.487708540254175,13.092443882188876,17.222376879481672,11.504247044865581,14.940633965549418,17.98798606513928,15.792832741672385,18.498793993537113,20.92396653814751 ...
# ...
# <div>                            <div id="04fb4f65-1030-4d1f-be1a-d9888441a957" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04fb4f65-1030-4d1f-be1a-d9888441a957")) {                    Plotly.newPlot(                        "04fb4f65-1030-4d1f-be1a-d9888441a957",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[26.833201270079638,31.22317647631359,23.189965070358838,31.23930454985806,28.219759892725335,27.720291589454277,31.127923387450153,30.92383159961451,25.324835169818144,29.13229951154206,28.62490629766575,30.608090420953268,32.20865457004637,35.41553009489617,26.446752487086403,26.846474852956117,24.68921381120526,27.714523426176708,31.05069443973973,32.62376119358895,29.54893448528399,35.3935405917793,29.68998445036211,24.270308581959974,26.192761934416293,27.374310960500626,29.522075329614317,29.409392197128668,33.32292981482438,26.628740920960734,27.995022457874033,26.12868405950164,25.89630650226579,27.077065277775976,24.430216375607884,25.53086126776299,26.299078011247854,30.68087300868619,33.299372786123115,30.382781784419908,28.344388771337645,30.80873796284281,26.86159788268183,29.105204485320016,31.298773372897582,27.932557802378586,31.03697621041746,25.13689893618506,31.97236156828129,28.562474868308243,32.058339022194254,27.366888706848613,32.11684814804373,28.14817341746232,26.71692878168067,34.8977226574319,27.45190838556702,25.317390868618958,31.92286353133583,27.152472183738716,23.809320702796427,31.34745832378811,30.523496252674562,26.462786129226323,32.812113946448896,31.570244065063854,30.232014890939194,23.22919015721527,30.25663233730044,32.69704421132474,30.254379181085394,28.745441508150748,29.2231424383341,27.033084319306937,24.29876617801998,28.263441721504797,30.1911636859198,25.607310199401653,28.732542985551113,28.11991188501116,26.292898738375314,31.746658118235906,34.29455278587286,23.32592331313576,25.359529711888808,28.51025765447115,34.040827866672565,26.871014492697086,32.453641317529296,26.445902360779016,26.50150115061551,28.277538411717437,29.104478413024243,25.087696103724173,26.432635739636034,30.95517215454355,28.89897017055789,29.65045225593141,28.03914309060432,27.631969237065167,25.129151949199553,25.673037120981007,29.456852965180307,27.460432924039402,22.54007796705222,27.3609373020722,27.912080652199528,25.924407669136983,30.637141510190144,27.657584692019242,28.74493028009883,27.171921971016218,28.88114882487322,23.690528829553394,34.154522663673646,19.427616183873305,26.410897181512286,29.455079238855333,31.131606095086084,24.53658773153249,23.839000386590065,27.642219196195757,24.646078637903955,27.28395001833649,28.142083602423444,32.02312226795028,23.64096982486545,23.044996926715008,31.031894723570193,28.85718711174153,30.440016911020646,31.458235214088383,29.89438858185953,25.62400015966918,32.574633120201064,25.917053361195983,31.82410496985701,18.57255089293966,31.323868628827537,30.596789347655278,28.66942115712813,30.321081462351774,26.449479380497934,24.7941294878363,27.718559955268223,30.421426170240846,28.81362598429407,36.74848513116452,32.57481700942761,28.848835713897028,26.690814147097498,28.11481235876091,24.972291674691014,27.790673483537727,28.744021328766973,26.529950042551828,32.847946998818564,32.40957320604301,26.47519997933867,26.310751510094104,27.742386405437102,29.153402977883978,26.463076899535174,32.22559602623904,30.929819355109736,28.55450203904009,25.456766420697623,30.39802004646365,30.336240327003342,25.709516113561953,30.29584842520264,26.39703169173949,30.147178455702896,24.63125694229884,27.622827737450784,28.893843951392327,28.702164582020426 ...
# <div>                            <div id="269b0e77-fc7f-4a48-90d2-27fd34b9fbbf" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("269b0e77-fc7f-4a48-90d2-27fd34b9fbbf")) {                    Plotly.newPlot(                        "269b0e77-fc7f-4a48-90d2-27fd34b9fbbf",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[37.81763707014046,36.8994659858658,28.738344845953442,36.0833213374349,33.36912267600612,35.17893262783255,33.43366363898699,36.52253618367898,36.98183432695668,28.220391074329424,37.04800278061251,34.25605858552868,31.592333083150393,34.698569440273374,31.420134647565423,32.15028780132862,34.351677166273205,40.12132338724511,36.2827550691098,32.33007924998594,37.330126064099545,31.781615000388715,32.59621894733784,32.27048852824692,32.45420979385082,35.00251890504936,36.26922436520365,29.017215127973778,33.51428277742596,30.03285848089166,34.032601503100636,37.87231463580114,34.55507759574404,35.28522120067229,33.15330774637409,35.003676328328176,34.08031476115334,33.37702780980888,35.06921086680381,35.152049780026005,33.87809717497706,36.439400546339506,32.43447097110991,37.170480126466344,33.91404138315543,35.1284818951251,36.152114584387746,37.42355078224096,34.70109049454588,31.374011162480027,34.94642096440962,39.591388674956754,43.998367028093334,37.68769678211029,35.98872679095922,38.24742159259276,25.15216322061591,36.276566148630245,36.139989258148155,35.60720825781275,31.78651525841968,41.47940475090975,31.056432764855664,32.28175815699605,36.0080450183897,35.56196361587669,29.004338765103746,34.563521833843254,36.70683663263186,40.12374790269313,36.508235508459926,34.499394172333325,29.459786132346903,31.386299865565608,29.96629144745112,32.13467799164598,37.13873378495094,35.97685391849672,35.61979996242048,36.15020833622484,30.941016626465476,37.86002530375866,33.57407977738014,36.452543147299664,37.32609670965577,32.81295487899459,36.2563576015343,30.787537194140608,40.50570344543344,33.81779461557161,35.04785466439517,33.280056935213246,30.49428647891561,38.75718558630542,35.90574561021774,38.76935565258342,38.905237960674825,33.86176783847879,29.744013544399838,34.310691175555036,34.9033686549051,34.81182266441504,35.4836685876025,33.114708386511964,35.93633412730179,36.15792751376071,32.72868610190771,36.91485394886327,33.20855154066061,39.563875667337406,32.86932174934051,35.975299495268935,28.978185894164582,33.94297742543106,31.040205888954077,29.68796103679107,33.59511169775895,32.937034944210616,32.687392200655545,34.219408407514585,37.825003437694605,32.40775504699294,32.71451153392083,30.639830355832004,37.9620741230633,30.55736053624571,30.753205188800845,30.43464008752208,33.67122311470191,35.438013502215114,29.441386924267203,31.42361043892119,29.662849949986345,37.354714374997045,33.47302437572542,29.889371369058487,31.49024812280485,29.55364663719112,37.32870062902529,34.72738291232625,39.98202377558146,31.592058307597444,32.71560589258867,32.92981628816051,30.665867655941675,31.061695132929046,33.10047588969974,34.827472404184476,31.112245440371108,37.88900110268237,34.35124081960709,34.56659893938003,25.39411712886947,32.67808075944791,31.518172495255985,32.40720230471994,31.170371911429186,32.32059254368791,34.508746227002355,31.689262592856053,35.36425456275928,31.46275803487653,36.337366434602295,41.000505954229396,33.040889309284324,35.161410802293254,38.291458152696265,37.936969706629476,35.00947838794488,30.17217990781096,31.197722564094914,38.33481534168267,34.973546793454176,36.902721475077456,33.20243782013495,29.758702673993536,31.25930112055049,35.49171260471065,34.80352671029813,31 ...
# <div>                            <div id="05e382ed-c519-4eb9-b095-4c831cfd8398" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05e382ed-c519-4eb9-b095-4c831cfd8398")) {                    Plotly.newPlot(                        "05e382ed-c519-4eb9-b095-4c831cfd8398",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[35.8139004761454,31.686860699896705,30.246472543662872,32.85238350645546,31.26888534328393,36.96214621640377,32.22635901316981,35.09204384032116,26.73715242778716,32.420504433401845,34.060290135215546,37.07631881779764,36.585997652240536,36.94501356944315,37.978078851224325,38.77536470663978,34.59799078142538,33.872492735640954,34.2379986195916,25.940182795979194,35.64450111841605,33.42468252802355,31.143462202549248,34.185215525977476,34.346252180402026,32.569810657924506,29.526872437321632,36.63951212883357,36.656067659846855,37.384599767724595,34.97545572647398,37.172283016241735,31.198710878173593,38.12943246887945,30.58145574241365,37.42441349756297,40.859431710382275,33.4859730465189,32.74536461643281,37.39583280236785,34.23634902673618,34.391206206954955,40.07839521867771,29.425099569102294,35.42491751405409,31.39153902100123,39.57107994672951,34.97297523289078,32.98724317125919,35.38350948314695,26.242023794392246,30.3989464149238,32.07182458757575,35.091569772462854,34.906131169874854,32.28356843870608,38.627541133106355,34.53184289105894,34.66511525351783,28.667775054758835,33.747202048042446,36.93383086985856,34.52812257634063,33.38170252631441,38.76877486296563,35.09107229593635,34.62960000346035,29.39973322756511,27.954751056854068,32.70575689262781,34.53459973110483,31.748088798460817,39.25656615404861,35.27763715339845,37.125042802488814,36.677773248473805,28.45236581101207,35.049937857049045,35.81759625628042,32.675777969863084,30.577665688229793,36.42602590529373,26.311636270850407,29.819829765178213,37.58369679432272,36.02420328044075,27.212910669811833,31.505317954964145,35.28790568106991,31.306877918554434,36.225232034031116,31.558867308677055,31.691099794992166,34.83545757693916,31.629778918328903,35.061403364159894,34.44469268363443,34.715429830585755,30.791407001120533,37.09130984801284,26.699237650273766,34.544333471231546,36.39279555083442,33.62967427692816,39.87112769966043,36.64691555872518,35.94247479077524,37.51014761244094,33.078005454867466,40.75458766916264,36.11569948627645,33.43917243495948,27.775066007249414,35.213613012084565,32.69773309829073,32.818031089029844,32.48609717969842,33.545383755558724,33.921978420918464,34.721223814446525,30.31678606354763,35.911281699797264,30.809957400506402,35.04384774049858,32.90462210841607,31.504886459281074,41.07690406014199,35.4945352426666,34.833031354572526,33.71760974601553,32.01569757952319,32.46461325794955,35.8299949890924,37.859427644594746,35.83463151584086,32.54862525471045,33.78059510814453,37.615868417384235,34.25472707932827,32.71177232502592,35.761889023675955,35.27979680243249,34.24372606406044,41.595882866135966,31.45665988158368,35.60884332354476,35.492640749347174,35.79085502555847,37.35795920251617,38.253326392059655,34.81730117761387,37.53541518630571,34.592969744026604,33.59116214164067,39.81720831710061,34.171419336100534,31.1465050150436,35.10296249304385,34.24509398575357,31.70824938722868,38.22900316210082,29.031013435725733,35.70034810177141,32.14683199910867,37.86898324795061,27.126508368858985,35.44975525343118,34.83284134279271,30.701447768162453,33.28113661630963,35.16404010476493,29.694227876741994,33.735402741211765,33.361558145690864,29.022877405056725,40.43269452536164,31.533378608061142,38.56593705594637,37.4071037884 ...
